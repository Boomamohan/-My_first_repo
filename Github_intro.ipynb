# %% [markdown]
# <a href="https://colab.research.google.com/github/Boomamohan/-My_first_repo/blob/main/Github_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Github!")
# Out:
# Hello Github!
